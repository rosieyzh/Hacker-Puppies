# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
breeds = pd.read_csv("sample_submission.csv")
breeds.head()
# Out:
#                                  id  affenpinscher  afghan_hound  \
# 0  000621fb3cbb32d8935728e48679680e       0.008333      0.008333
# 1  00102ee9d8eb90812350685311fe5890       0.008333      0.008333
# 2  0012a730dfa437f5f3613fb75efcd4ce       0.008333      0.008333
# 3  001510bc8570bbeee98c8d80c8a95ec1       0.008333      0.008333
# 4  001a5f3114548acdefa3d4da05474c2e       0.008333      0.008333
#
#    african_hunting_dog  airedale  american_staffordshire_terrier  appenzeller  \
# 0             0.008333  0.008333                        0.008333     0.008333
# 1             0.008333  0.008333                        0.008333     0.008333
# 2             0.008333  0.008333                        0.008333     0.008333
# 3             0.008333  0.008333                        0.008333     0.008333
# 4             0.008333  0.008333                        0.008333     0.008333
#
#    australian_terrier   basenji    basset        ...          toy_poodle  \
# 0            0.008333  0.008333  0.008333        ...            0.008333
# 1            0.008333  0.008333  0.008333        ...            0.008333
# 2            0.008333  0.008333  0.008333        ...            0.008333
# 3            0.008333  0.008333  0.008333        ...            0.008333
# 4            0.008333  0.008333  0.008333        ...            0.008333
#
#    toy_terrier    vizsla  walker_hound  weimaraner  welsh_springer_spaniel  \
# 0     0.008333  0.008333      0.008333    0.008333                0.008333
# 1     0.008333  0.008333      0.008333    0.008333                0.008333
# 2     0.008333  0.008333      0.008333    0.008333                0.008333
# 3     0.008333  0.008333      0.008333    0.008333                0.008333
# 4     0.008333  0.008333      0.008333    0.008333                0.008333
#
#    west_highland_white_terrier   whippet  wire-haired_fox_terrier  \
# 0                     0.008333  0.008333                 0.008333
# 1                     0.008333  0.008333                 0.008333
# 2                     0.008333  0.008333                 0.008333
# 3                     0.008333  0.008333                 0.008333
# 4                     0.008333  0.008333                 0.008333
#
#    yorkshire_terrier
# 0           0.008333
# 1           0.008333
# 2           0.008333
# 3           0.008333
# 4           0.008333
#
# [5 rows x 121 columns]

# %%
from keras.preprocessing import image
from keras.applications.inception_resnet_v2 import preprocess_input, decode_predictions

img = breeds['id'][0]

mage = image.load_img("test/" + img + ".jpg", target_size=(299, 299))
data = image.img_to_array(mage)
data = preprocess_input(np.expand_dims(mage, axis = 0))

# %%
from keras.models import load_model

model = load_model('model.h5')

# %%
y_pred = model.predict(data)

# %%
y_pred

# %%
import pickle
with open('encoder.pkl','rb') as f:
    one_hot = pickle.load(f)
    f.close()

# %%
def un_onehot(data):
    breed = one_hot.inverse_transform(data)
    return breed

# %%
y_pred

# %%
label = un_onehot(y_pred)

# %%
label

# %%
zero = np.identity(120)

# %%
breeds_1.to_frame()
# Out:
#                                                                0
# id                              000621fb3cbb32d8935728e48679680e
# affenpinscher                                         0.00833333
# afghan_hound                                          0.00833333
# african_hunting_dog                                   0.00833333
# airedale                                              0.00833333
# american_staffordshire_terrier                        0.00833333
# appenzeller                                           0.00833333
# australian_terrier                                    0.00833333
# basenji                                               0.00833333
# basset                                                0.00833333
# beagle                                                0.00833333
# bedlington_terrier                                    0.00833333
# bernese_mountain_dog                                  0.00833333
# black-and-tan_coonhound                               0.00833333
# blenheim_spaniel                                      0.00833333
# bloodhound                                            0.00833333
# bluetick                                              0.00833333
# border_collie                                         0.00833333
# border_terrier                                        0.00833333
# borzoi                                                0.00833333
# boston_bull                                           0.00833333
# bouvier_des_flandres                                  0.00833333
# boxer                                                 0.00833333
# brabancon_griffon                                     0.00833333
# briard                                                0.00833333
# brittany_spaniel                                      0.00833333
# bull_mastiff                                          0.00833333
# cairn                                                 0.00833333
# cardigan                                              0.00833333
# chesapeake_bay_retriever                              0.00833333
# ...                                                          ...
# rhodesian_ridgeback                                   0.00833333
# rottweiler                                            0.00833333
# saint_bernard                                         0.00833333
# saluki                                                0.00833333
# samoyed                                               0.00833333
# schipperke                                            0.00833333
# scotch_terrier                                        0.00833333
# scottish_deerhound                                    0.00833333
# sealyham_terrier                                      0.00833333
# shetland_sheepdog                                     0.00833333
# shih-tzu                                              0.00833333
# siberian_husky                                        0.00833333
# silky_terrier                                         0.00833333
# soft-coated_wheaten_terrier                           0.00833333
# staffordshire_bullterrier                             0.00833333
# standard_poodle                                       0.00833333
# standard_schnauzer                                    0.00833333
# sussex_spaniel                                        0.00833333
# tibetan_mastiff                                       0.00833333
# tibetan_terrier                                       0.00833333
# toy_poodle                                            0.00833333
# toy_terrier                                           0.00833333
# vizsla                                                0.00833333
# walker_hound                                          0.00833333
# weimaraner                                            0.00833333
# welsh_springer_spaniel                                0.00833333
# west_highland_white_terrier                           0.00833333
# whippet                                               0.00833333
# wire-haired_fox_terrier                               0.00833333
# yorkshire_terrier                                     0.00833333
#
# [121 rows x 1 columns]

# %%
breeds_1 = breeds.iloc[0]

# %%
breeds_2 = breeds.iloc[0,].max
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-14c15691cb8d> in <module>
# ----> 1 breeds_2 = breeds.iloc[0,].max
#
# AttributeError: 'str' object has no attribute 'max'

# %%
breeds = []
for i in range(120):
    breeds.append(un_onehot(np.array(zero[i])))

# %%
df = df[0]
df

# %%
trulab = un_onehot(np.array(df[1].values))
